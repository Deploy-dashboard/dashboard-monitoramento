# %%
import pandas as pd

flu = "progresso_fluencia.csv"
cor = "progresso_correcao.csv"

df = pd.DataFrame(pd.read_csv("progresso.csv"))
s = pd.DataFrame(pd.read_csv("progresso_somativa.csv"))
f = pd.DataFrame(pd.read_csv("progresso_formativa.csv"))

print(df.columns)
print(s.columns)
print(f.columns)

# dflu = pd.DataFrame(pd.read_csv(flu))
# dcor = pd.DataFrame(pd.read_csv(cor))
# Out:
# Index(['subprograma', 'nome', 'dv_banco', 'dv_producao', 'frop1', 'frop1_ret',
#        'frop2', 'frop3', 'imagem', 'conf_hmg', 'conf_pro_t1', 'recuperacao',
#        'recuperacao_t2', 'nm_aluno', 'categorizacao_tn', 'rel_categroizacao',
#        'certif_obj', 'certif_ctx', 'certif_nap', 'certif_esc', 'certif_sinc',
#        'certif_co', 'co_rel_pgto', 'medida_obj', 'medida_ctx', 'medida_esc',
#        'pareamento', 'rel_tratamento', 'rel_verificacao'],
#       dtype='object')
# Index(['subprograma', 'nome', 'dv_banco', 'dv_producao', 'frop1', 'frop1_ret',
#        'frop2', 'frop3', 'imagem', 'conf_hmg', 'conf_pro_t1', 'recuperacao',
#        'recuperacao_t2', 'nm_aluno', 'categorizacao_tn', 'rel_categroizacao',
#        'certif_obj', 'certif_ctx', 'certif_nap', 'certif_esc', 'certif_sinc',
#        'certif_co', 'co_rel_pgto', 'medida_obj', 'medida_ctx', 'medida_esc',
#        'pareamento', 'rel_tratamento', 'rel_verificacao'],
#       dtype='object')
# ...

# %%
print(s.columns)

news = s.copy()
news = news[['subprograma', 'nome', 'dv_banco',
'dv_producao',
'frop1',
'frop1_ret',
'frop2',
'frop3',
'recuperacao',
'recuperacao_t2',
'recuperacao_ex',
'recuperacao_ex_ret',
'nm_aluno',
'categorizacao_tn',
'rel_categroizacao',
'certif_obj',
'certif_ctx',
'certif_nap',
'medida_obj',
'medida_ctx',
'rel_tratamento',
'rel_verificacao']]

print(news.columns)
# Out:
# Index(['subprograma', 'nome', 'dv_banco', 'dv_producao', 'frop1', 'frop1_ret',
#        'frop2', 'frop3', 'imagem', 'conf_hmg', 'conf_pro_t1', 'recuperacao',
#        'recuperacao_t2', 'recuperacao_ex', 'recuperacao_ex_ret', 'nm_aluno',
#        'categorizacao_tn', 'rel_categroizacao', 'certif_obj', 'certif_ctx',
#        'certif_nap', 'certif_esc', 'certif_sinc', 'certif_co', 'co_rel_pgto',
#        'medida_obj', 'medida_ctx', 'medida_esc', 'pareamento',
#        'rel_tratamento', 'rel_verificacao'],
#       dtype='object')
# Index(['subprograma', 'nome', 'dv_banco', 'dv_producao', 'frop1', 'frop1_ret',
#        'frop2', 'frop3', 'recuperacao', 'recuperacao_t2', 'recuperacao_ex',
#        'recuperacao_ex_ret', 'nm_aluno', 'categorizacao_tn',
#        'rel_categroizacao', 'certif_obj', 'certif_ctx', 'certif_nap',
#        'medida_obj', 'medida_ctx', 'rel_tratamento', 'rel_verificacao'],
#       dtype='object')

# %%
news.to_csv("progresso_somativa.csv", index=False)
